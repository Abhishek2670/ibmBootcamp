# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.utils import to_categorical

# load dataset safely
with open('story.txt', 'r', encoding="utf-8") as f:
    text = f.read().lower()

chars = sorted(list(set(text)))
char_to_index = {char: idx for idx, char in enumerate(chars)}
index_to_char = {idx: char for idx, char in enumerate(chars)}

encoded_text = [char_to_index[c] for c in text]

seq_length = 40
x, y = [], []

for i in range(len(encoded_text) - seq_length):
    x.append(encoded_text[i:i + seq_length])
    y.append(encoded_text[i + seq_length])

x = np.array(x)
y = to_categorical(y, num_classes=len(chars))

# build model
model = Sequential([
    Embedding(len(chars), 50, input_length=seq_length),
    SimpleRNN(128),
    Dense(len(chars), activation='softmax')
])

model.compile(loss='categorical_crossentropy', optimizer='adam')
model.summary()

# train
model.fit(x, y, epochs=20, batch_size=128)

# text generation
def generate_text(seed, length=200):
    seed = seed.lower()

    if len(seed) < seq_length:
        seed = " " * (seq_length - len(seed)) + seed

    result = seed

    for _ in range(length):
        encoded = np.array([[char_to_index[c] for c in result[-seq_length:]]])
        preds = model.predict(encoded, verbose=0)[0]
        next_char = index_to_char[np.argmax(preds)]
        result += next_char

    return result

# run
seed_text = "machine learning in branch"
generated = generate_text(seed_text)

print("\nGenerated Text:\n")
print(generated)

with open('sample_output.txt', 'w') as f:
    f.write(generated)
# Out:
# c:\Users\asus\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.9221
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7219
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6369
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5701
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5226
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4638
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.3752
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.2834
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2123
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1489
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0929
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0434
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.9990
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9610
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.9275
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9010
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8822
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8452
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8106
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7853
#
# Generated Text:
#
#               machine learning in branche  and and and and the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the the t
